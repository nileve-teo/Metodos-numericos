# %% [markdown]
# <a href="https://colab.research.google.com/github/nileve-teo/M-todos-num-ricos/blob/main/TAREA_SEMANA08.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <div style="
#     font-family:'Baskerville Old Face';
#     font-size:55px;
#     color:black;
#     font-weight:bold;
#     text-align:center;
#     margin-top:25px;
#     margin-bottom:30px;
# ">
# Procesamiento Numérico de Señales en un Sistema de Telemetría Biomédica Inalámbrica
# </div>

# %% [markdown]
# <div style="
# font-family:Helvetica Now Micro Condensed Bold;
# font-size:11pt;
# color:white;
# background-color:rgb(15,150,103);
# padding:6px 14px;
# font-weight:bold;
# display:inline-block;
# border-bottom:4px solid rgb(15,150,103);
# margin-bottom:15px;
# ">
# CONTEXTO
# </div>
#
# <div style="
# font-family:'Times New Roman', serif;
# font-size:11pt;
# color:black;
# text-align:justify;
# line-height:1.6;
# ">
#
# En un sistema de telemetría biomédica inalámbrica, un sensor piezoeléctrico implantable mide la deformación mecánica de un tejido y transmite una señal de voltaje a un módulo de procesamiento electrónico. El sistema se usa para monitorear micro vibraciones asociadas con flujo sanguíneo y actividad muscular.
#
# Durante una calibración de laboratorio, se registró el voltaje de salida del sensor en función del tiempo, en milisegundos. Se sospecha que la señal presenta un cambio de signo asociado con una condición crítica de activación del circuito y, además, que la velocidad de cambio del voltaje permite evaluar la respuesta dinámica del biosensor.
#
# </div>
#
# <br>
#
# <table style="
# border-collapse:collapse;
# width:100%;
# font-family:'Dutch 801' ;
# font-size:11pt;
# ">
#
# <tr>
#
# <th style="border:1px solid black;padding:8px;background-color:rgb(15,150,103);color:white;">
# Tiempo (ms)
# </th>
#
# <td style="border:1px solid black;padding:8px;">0.0</td>
# <td style="border:1px solid black;padding:8px;">0.5</td>
# <td style="border:1px solid black;padding:8px;">1.0</td>
# <td style="border:1px solid black;padding:8px;">1.5</td>
# <td style="border:1px solid black;padding:8px;">2.0</td>
# <td style="border:1px solid black;padding:8px;">2.5</td>
# <td style="border:1px solid black;padding:8px;">3.0</td>
# <td style="border:1px solid black;padding:8px;">3.5</td>
# <td style="border:1px solid black;padding:8px;">4.0</td>
# <td style="border:1px solid black;padding:8px;">4.5</td>
# <td style="border:1px solid black;padding:8px;">5.0</td>
# <td style="border:1px solid black;padding:8px;">5.5</td>
# <td style="border:1px solid black;padding:8px;">6.0</td>
# <td style="border:1px solid black;padding:8px;">6.5</td>
# <td style="border:1px solid black;padding:8px;">7.0</td>
# <td style="border:1px solid black;padding:8px;">7.5</td>
#
# </tr>
#
# <tr>
#
# <th style="border:1px solid black;padding:8px;background-color:rgb(15,150,103);color:white;">
# Voltaje (V)
# </th>
#
# <td style="border:1px solid black;padding:8px;">4.8120</td>
# <td style="border:1px solid black;padding:8px;">4.2635</td>
# <td style="border:1px solid black;padding:8px;">3.7541</td>
# <td style="border:1px solid black;padding:8px;">3.2804</td>
# <td style="border:1px solid black;padding:8px;">2.8387</td>
# <td style="border:1px solid black;padding:8px;">2.4236</td>
# <td style="border:1px solid black;padding:8px;">2.0314</td>
# <td style="border:1px solid black;padding:8px;">1.6583</td>
# <td style="border:1px solid black;padding:8px;">1.3011</td>
# <td style="border:1px solid black;padding:8px;">1.2574</td>
# <td style="border:1px solid black;padding:8px;">1.1460</td>
# <td style="border:1px solid black;padding:8px;">0.8624</td>
# <td style="border:1px solid black;padding:8px;">0.6048</td>
# <td style="border:1px solid black;padding:8px;">0.3720</td>
# <td style="border:1px solid black;padding:8px;">0.1672</td>
# <td style="border:1px solid black;padding:8px;">-0.0186</td>
#
# </tr>
#
# </table>
# <br>
#
# <table style="
# border-collapse:collapse;
# width:100%;
# font-family:'Dutch 801';
# font-size:11pt;
# ">
#
# <tr>
#
# <th style="border:1px solid black;padding:8px;background-color:rgb(15,150,103);color:white;">
# Tiempo (ms)
# </th>
#
# <td style="border:1px solid black;padding:8px;">8.0</td>
# <td style="border:1px solid black;padding:8px;">8.5</td>
# <td style="border:1px solid black;padding:8px;">9.0</td>
# <td style="border:1px solid black;padding:8px;">9.5</td>
# <td style="border:1px solid black;padding:8px;">10.0</td>
# <td style="border:1px solid black;padding:8px;">10.5</td>
# <td style="border:1px solid black;padding:8px;">11.0</td>
# <td style="border:1px solid black;padding:8px;">11.5</td>
# <td style="border:1px solid black;padding:8px;">12.0</td>
# <td style="border:1px solid black;padding:8px;">12.5</td>
# <td style="border:1px solid black;padding:8px;">13.0</td>
# <td style="border:1px solid black;padding:8px;">13.5</td>
# <td style="border:1px solid black;padding:8px;">14.0</td>
# <td style="border:1px solid black;padding:8px;">14.5</td>
# <td style="border:1px solid black;padding:8px;">15.0</td>
#
# </tr>
#
# <tr>
#
# <th style="border:1px solid black;padding:8px;background-color:rgb(15,150,103);color:white;">
# Voltaje (V)
# </th>
#
# <td style="border:1px solid black;padding:8px;">-0.1805</td>
# <td style="border:1px solid black;padding:8px;">-0.3142</td>
# <td style="border:1px solid black;padding:8px;">-0.3148</td>
# <td style="border:1px solid black;padding:8px;">-0.2769</td>
# <td style="border:1px solid black;padding:8px;">-0.2100</td>
# <td style="border:1px solid black;padding:8px;">0.0483</td>
# <td style="border:1px solid black;padding:8px;">0.2931</td>
# <td style="border:1px solid black;padding:8px;">0.5185</td>
# <td style="border:1px solid black;padding:8px;">0.7214</td>
# <td style="border:1px solid black;padding:8px;">0.8982</td>
# <td style="border:1px solid black;padding:8px;">1.0456</td>
# <td style="border:1px solid black;padding:8px;">1.1618</td>
# <td style="border:1px solid black;padding:8px;">1.2465</td>
# <td style="border:1px solid black;padding:8px;">1.3001</td>
# <td style="border:1px solid black;padding:8px;">1.3228</td>
#
# </tr>
#
# </table>
# <br>
#
# <div style="
# font-family:Arial, sans-serif;
# font-size:11pt;
# color:white;
# background-color:rgb(15,150,103);
# padding:6px 14px;
# font-weight:bold;
# display:inline-block;
# border-bottom:4px solid rgb(15,150,103);
# margin-bottom:15px;
# ">
# ENUNCIADO
# </div>
#
# <div style="
# font-family:'Times New Roman', serif;
# font-size:11pt;
# color:black;
# text-align:justify;
# line-height:1.6;
# ">
#
# Usted es el ingeniero responsable del procesamiento numérico de la señal y debe responder a los siguientes requerimientos.
#
# </div>

# %% [markdown]
# <div style="width:21cm; margin:auto;">
#
# <div style="
# font-family:'Helvetica Now Micro Condensed Bold';
# font-size:11pt;
# color:white;
# background-color:rgb(15,150,103);
# padding:6px 14px;
# font-weight:bold;
# display:inline-block;
# border-bottom:4px solid rgb(15,150,103);
# margin-bottom:15px;
# ">
# CONTEXTO
# </div>
#
# <div style="
# font-family:'Times New Roman', serif;
# font-size:11pt;
# color:black;
# text-align:justify;
# line-height:1.6;
# ">
#
# En un sistema de telemetría biomédica inalámbrica, un sensor piezoeléctrico implantable mide la deformación mecánica de un tejido y transmite una señal de voltaje a un módulo de procesamiento electrónico. El sistema se usa para monitorear micro vibraciones asociadas con flujo sanguíneo y actividad muscular.
#
# Durante una calibración de laboratorio, se registró el voltaje de salida del sensor en función del tiempo, en milisegundos. Se sospecha que la señal presenta un cambio de signo asociado con una condición crítica de activación del circuito y, además, que la velocidad de cambio del voltaje permite evaluar la respuesta dinámica del biosensor.
#
# </div>
#
# <br>
#
# <!-- ================= TABLA 1 ================= -->
#
# <table style="
# border-collapse:collapse;
# width:100%;
# font-family:'Dutch 801';
# font-size:11pt;
# table-layout:fixed;
# ">
#
# <tr>
#
# <th style="border:1px solid black;padding:8px;background-color:rgb(15,150,103);color:white;">
# Tiempo (ms)
# </th>
#
# <td style="border:1px solid black;padding:8px;">0.0</td>
# <td style="border:1px solid black;padding:8px;">0.5</td>
# <td style="border:1px solid black;padding:8px;">1.0</td>
# <td style="border:1px solid black;padding:8px;">1.5</td>
# <td style="border:1px solid black;padding:8px;">2.0</td>
# <td style="border:1px solid black;padding:8px;">2.5</td>
# <td style="border:1px solid black;padding:8px;">3.0</td>
# <td style="border:1px solid black;padding:8px;">3.5</td>
# <td style="border:1px solid black;padding:8px;">4.0</td>
# <td style="border:1px solid black;padding:8px;">4.5</td>
#
# </tr>
#
# <tr>
#
# <th style="border:1px solid black;padding:8px;background-color:rgb(15,150,103);color:white;">
# Voltaje (V)
# </th>
#
# <td style="border:1px solid black;padding:8px;">4.8120</td>
# <td style="border:1px solid black;padding:8px;">4.2635</td>
# <td style="border:1px solid black;padding:8px;">3.7541</td>
# <td style="border:1px solid black;padding:8px;">3.2804</td>
# <td style="border:1px solid black;padding:8px;">2.8387</td>
# <td style="border:1px solid black;padding:8px;">2.4236</td>
# <td style="border:1px solid black;padding:8px;">2.0314</td>
# <td style="border:1px solid black;padding:8px;">1.6583</td>
# <td style="border:1px solid black;padding:8px;">1.3011</td>
# <td style="border:1px solid black;padding:8px;">1.2574</td>
#
# </tr>
#
# </table>
#
# <br>
#
# <!-- ================= TABLA 2 ================= -->
#
# <table style="
# border-collapse:collapse;
# width:100%;
# font-family:'Dutch 801';
# font-size:11pt;
# table-layout:fixed;
# ">
#
# <tr>
#
# <th style="border:1px solid black;padding:8px;background-color:rgb(15,150,103);color:white;">
# Tiempo (ms)
# </th>
#
# <td style="border:1px solid black;padding:8px;">5.0</td>
# <td style="border:1px solid black;padding:8px;">5.5</td>
# <td style="border:1px solid black;padding:8px;">6.0</td>
# <td style="border:1px solid black;padding:8px;">6.5</td>
# <td style="border:1px solid black;padding:8px;">7.0</td>
# <td style="border:1px solid black;padding:8px;">7.5</td>
# <td style="border:1px solid black;padding:8px;">8.0</td>
# <td style="border:1px solid black;padding:8px;">8.5</td>
# <td style="border:1px solid black;padding:8px;">9.0</td>
# <td style="border:1px solid black;padding:8px;">9.5</td>
#
# </tr>
#
# <tr>
#
# <th style="border:1px solid black;padding:8px;background-color:rgb(15,150,103);color:white;">
# Voltaje (V)
# </th>
#
# <td style="border:1px solid black;padding:8px;">1.1460</td>
# <td style="border:1px solid black;padding:8px;">0.8624</td>
# <td style="border:1px solid black;padding:8px;">0.6048</td>
# <td style="border:1px solid black;padding:8px;">0.3720</td>
# <td style="border:1px solid black;padding:8px;">0.1672</td>
# <td style="border:1px solid black;padding:8px;">-0.0186</td>
# <td style="border:1px solid black;padding:8px;">-0.1805</td>
# <td style="border:1px solid black;padding:8px;">-0.3142</td>
# <td style="border:1px solid black;padding:8px;">-0.3148</td>
# <td style="border:1px solid black;padding:8px;">-0.2769</td>
#
# </tr>
#
# </table>
#
# <br>
#
# <!-- ================= TABLA 3 ================= -->
#
# <table style="
# border-collapse:collapse;
# width:100%;
# font-family:'Dutch 801';
# font-size:11pt;
# table-layout:fixed;
# ">
#
# <tr>
#
# <th style="border:1px solid black;padding:8px;background-color:rgb(15,150,103);color:white;">
# Tiempo (ms)
# </th>
#
# <td style="border:1px solid black;padding:8px;">10.0</td>
# <td style="border:1px solid black;padding:8px;">10.5</td>
# <td style="border:1px solid black;padding:8px;">11.0</td>
# <td style="border:1px solid black;padding:8px;">11.5</td>
# <td style="border:1px solid black;padding:8px;">12.0</td>
# <td style="border:1px solid black;padding:8px;">12.5</td>
# <td style="border:1px solid black;padding:8px;">13.0</td>
# <td style="border:1px solid black;padding:8px;">13.5</td>
# <td style="border:1px solid black;padding:8px;">14.0</td>
# <td style="border:1px solid black;padding:8px;">14.5</td>
# <td style="border:1px solid black;padding:8px;">15.0</td>
#
# </tr>
#
# <tr>
#
# <th style="border:1px solid black;padding:8px;background-color:rgb(15,150,103);color:white;">
# Voltaje (V)
# </th>
#
# <td style="border:1px solid black;padding:8px;">-0.2100</td>
# <td style="border:1px solid black;padding:8px;">0.0483</td>
# <td style="border:1px solid black;padding:8px;">0.2931</td>
# <td style="border:1px solid black;padding:8px;">0.5185</td>
# <td style="border:1px solid black;padding:8px;">0.7214</td>
# <td style="border:1px solid black;padding:8px;">0.8982</td>
# <td style="border:1px solid black;padding:8px;">1.0456</td>
# <td style="border:1px solid black;padding:8px;">1.1618</td>
# <td style="border:1px solid black;padding:8px;">1.2465</td>
# <td style="border:1px solid black;padding:8px;">1.3001</td>
# <td style="border:1px solid black;padding:8px;">1.3228</td>
#
# </tr>
#
# </table>
#
# <br>
#
# <div style="
# font-family:Arial, sans-serif;
# font-size:11pt;
# color:white;
# background-color:rgb(15,150,103);
# padding:6px 14px;
# font-weight:bold;
# display:inline-block;
# border-bottom:4px solid rgb(15,150,103);
# margin-bottom:15px;
# ">
# ENUNCIADO
# </div>
#
# <div style="
# font-family:'Times New Roman', serif;
# font-size:11pt;
# color:black;
# text-align:justify;
# line-height:1.6;
# ">
#
# Usted es el ingeniero responsable del procesamiento numérico de la señal y debe responder a los siguientes requerimientos.
#
# </div>
#
# </div>
