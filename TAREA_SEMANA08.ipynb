# %% [markdown]
# <a href="https://colab.research.google.com/github/nileve-teo/M-todos-num-ricos/blob/main/TAREA_SEMANA08.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ============================================================
# # CONFIGURACIÓN DE ESTILO PARA GOOGLE COLAB + MARKDOWN HTML
# # ============================================================
#
# from IPython.display import display, HTML
#
# display(HTML("""
# <style>
#
# /* ===== TÍTULO PRINCIPAL ===== */
# .titulo-principal{
#     font-family:'Baskerville Old Face', serif;
#     font-size:44px;
#     color:black;
#     font-weight:bold;
#     text-align:center;
#     margin-top:20px;
#     margin-bottom:30px;
# }
#
# /* ===== SUBTÍTULOS ===== */
# .subtitulo{
#     font-family:'HelveticaNowText Bold', sans-serif;
#     font-size:24px;
#     color:black;
#     background-color:#A9D18E;
#     display:inline-block;
#     padding:6px 14px;
#     border-bottom:6px solid #70AD47;
#     margin-top:25px;
#     margin-bottom:15px;
#     font-weight:bold;
# }
#
# /* ===== ENUNCIADOS ===== */
# .enunciado{
#     font-family:'Times New Roman', serif;
#     font-size:11pt;
#     text-align:justify;
#     line-height:1.6;
#     color:black;
# }
#
# /* ===== PALABRA SOLUCIÓN ===== */
# .solucion{
#     font-family:'Times New Roman', serif;
#     font-size:10pt;
#     color:rgb(15,150,103);
#     background-color:rgb(247,239,219);
#     display:inline-block;
#     padding:4px 10px;
#     text-decoration:underline;
#     font-weight:bold;
#     margin-top:15px;
#     margin-bottom:10px;
# }
#
# /* ===== TEXTO NORMAL ===== */
# .texto{
#     font-family:'Times New Roman', serif;
#     font-size:12pt;
#     color:black;
#     text-align:justify;
# }
#
# </style>
# """))

# %%
# ============================================================
# CONFIGURACIÓN DE ESTILO PARA GOOGLE COLAB + MARKDOWN HTML
# ============================================================

from IPython.display import display, HTML

display(HTML("""
<style>

/* ===== TÍTULO PRINCIPAL ===== */
.titulo-principal{
    font-family:'Baskerville Old Face', serif;
    font-size:44px;
    color:black;
    font-weight:bold;
    text-align:center;
    margin-top:20px;
    margin-bottom:30px;
}

/* ===== SUBTÍTULOS ===== */
.subtitulo{
    font-family:'HelveticaNowText Bold', sans-serif;
    font-size:24px;
    color:black;
    background-color:#A9D18E;
    display:inline-block;
    padding:6px 14px;
    border-bottom:6px solid #70AD47;
    margin-top:25px;
    margin-bottom:15px;
    font-weight:bold;
}

/* ===== ENUNCIADOS ===== */
.enunciado{
    font-family:'Times New Roman', serif;
    font-size:11pt;
    text-align:justify;
    line-height:1.6;
    color:black;
}

/* ===== PALABRA SOLUCIÓN ===== */
.solucion{
    font-family:'Times New Roman', serif;
    font-size:10pt;
    color:rgb(15,150,103);
    background-color:rgb(247,239,219);
    display:inline-block;
    padding:4px 10px;
    text-decoration:underline;
    font-weight:bold;
    margin-top:15px;
    margin-bottom:10px;
}

/* ===== TEXTO NORMAL ===== */
.texto{
    font-family:'Times New Roman', serif;
    font-size:12pt;
    color:black;
    text-align:justify;
}

</style>
"""))
# Out:
# <style>
#
# /* ===== TÍTULO PRINCIPAL ===== */
# .titulo-principal{
#     font-family:'Baskerville Old Face', serif;
#     font-size:44px;
#     color:black;
#     font-weight:bold;
#     text-align:center;
#     margin-top:20px;
#     margin-bottom:30px;
# }
#
# /* ===== SUBTÍTULOS ===== */
# .subtitulo{
#     font-family:'HelveticaNowText Bold', sans-serif;
#     font-size:24px;
#     color:black;
#     background-color:#A9D18E;
#     display:inline-block;
#     padding:6px 14px;
#     border-bottom:6px solid #70AD47;
#     margin-top:25px;
#     margin-bottom:15px;
#     font-weight:bold;
# }
#
# /* ===== ENUNCIADOS ===== */
# .enunciado{
#     font-family:'Times New Roman', serif;
#     font-size:11pt;
#     text-align:justify;
#     line-height:1.6;
#     color:black;
# }
#
# /* ===== PALABRA SOLUCIÓN ===== */
# .solucion{
#     font-family:'Times New Roman', serif;
#     font-size:10pt;
#     color:rgb(15,150,103);
#     background-color:rgb(247,239,219);
#     display:inline-block;
#     padding:4px 10px;
#     text-decoration:underline;
#     font-weight:bold;
#     margin-top:15px;
#     margin-bottom:10px;
# }
#
# /* ===== TEXTO NORMAL ===== */
# .texto{
#     font-family:'Times New Roman', serif;
#     font-size:12pt;
#     color:black;
#     text-align:justify;
# }
#
# </style>

# %% [markdown]
# from IPython.display import Markdown, display
#
# display(Markdown("""
# <div class='titulo-principal'>
# Procesamiento Numérico de Señales Biomédicas en un Sistema de Telemetría Inalámbrica
# </div>
# """))
